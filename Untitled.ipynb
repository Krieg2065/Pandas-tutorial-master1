# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.options.display.max_rows = 8

# %%
df = pd.read_csv("data/vaccini.csv")

# %%
df.head(10)
# Out:
#    data_somministrazione        fornitore area fascia_anagrafica  \
# 0             2020-12-27  Pfizer/BioNTech  ABR             20-29
# 1             2020-12-27  Pfizer/BioNTech  ABR             30-39
# 2             2020-12-27  Pfizer/BioNTech  ABR             40-49
# 3             2020-12-27  Pfizer/BioNTech  ABR             50-59
# ..                   ...              ...  ...               ...
# 6             2020-12-27  Pfizer/BioNTech  ABR             80-89
# 7             2020-12-27  Pfizer/BioNTech  BAS             20-29
# 8             2020-12-27  Pfizer/BioNTech  BAS             30-39
# 9             2020-12-27  Pfizer/BioNTech  BAS             40-49
#
#     sesso_maschile  sesso_femminile  \
# 0                1                0
# 1                1                3
# 2                1                6
# 3                4                5
# ..             ...              ...
# 6                1                0
# 7                4                5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37059 entries, 0 to 37058
# Data columns (total 22 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   data_somministrazione                       37059 non-null  object
#  1   fornitore                                   37059 non-null  object
#  2   area                                        37059 non-null  object
#  3   fascia_anagrafica                           37059 non-null  object
#  4   sesso_maschile                              37059 non-null  int64
#  5   sesso_femminile                             37059 non-null  int64
#  6   categoria_operatori_sanitari_sociosanitari  37059 non-null  int64
#  7   categoria_personale_non_sanitario           37059 non-null  int64
#  8   categoria_ospiti_rsa                        37059 non-null  int64
#  9   categoria_60_69                             37059 non-null  int64
# ...

# %%
df.count()
# Out:
# data_somministrazione    37059
# fornitore                37059
# area                     37059
# fascia_anagrafica        37059
#                          ...
# codice_NUTS1             37059
# codice_NUTS2             37059
# codice_regione_ISTAT     37059
# nome_area                37059
# Length: 22, dtype: int64

# %%
df[['sesso_maschile', 'sesso_femminile']]
# Out:
#        sesso_maschile  sesso_femminile
# 0                   1                0
# 1                   1                3
# 2                   1                6
# 3                   4                5
# ...               ...              ...
# 37055              16               14
# 37056              73              127
# 37057               2                0
# 37058               2                3
#
# [37059 rows x 2 columns]

# %%
df[19:30]
# Out:
#    data_somministrazione        fornitore area fascia_anagrafica  \
# 19            2020-12-27  Pfizer/BioNTech  CAM             40-49
# 20            2020-12-27  Pfizer/BioNTech  CAM             50-59
# 21            2020-12-27  Pfizer/BioNTech  CAM             60-69
# 22            2020-12-27  Pfizer/BioNTech  CAM             70-79
# ..                   ...              ...  ...               ...
# 26            2020-12-27  Pfizer/BioNTech  EMR             50-59
# 27            2020-12-27  Pfizer/BioNTech  EMR             60-69
# 28            2020-12-27  Pfizer/BioNTech  EMR             70-79
# 29            2020-12-27  Pfizer/BioNTech  EMR             80-89
#
#     sesso_maschile  sesso_femminile  \
# 19              80               87
# 20             119               77
# 21             130               37
# 22               5                0
# ..             ...              ...
# 26              70              217
# 27              99               51
# ...

# %%
df.loc[df['nome_area'] == 'Lombardia']
# Out:
#       data_somministrazione                fornitore area fascia_anagrafica  \
# 50               2020-12-27          Pfizer/BioNTech  LOM             20-29
# 51               2020-12-27          Pfizer/BioNTech  LOM             30-39
# 52               2020-12-27          Pfizer/BioNTech  LOM             40-49
# 53               2020-12-27          Pfizer/BioNTech  LOM             50-59
# ...                     ...                      ...  ...               ...
# 37000            2021-04-19  Vaxzevria (AstraZeneca)  LOM             60-69
# 37001            2021-04-19  Vaxzevria (AstraZeneca)  LOM             70-79
# 37002            2021-04-19  Vaxzevria (AstraZeneca)  LOM             80-89
# 37003            2021-04-19  Vaxzevria (AstraZeneca)  LOM               90+
#
#        sesso_maschile  sesso_femminile  \
# 50                 20               22
# 51                 31               33
# 52                 62               80
# 53                114              119
# ...

# %%
array = ['Lombardia', 'Piemonte']
df.loc[df['nome_area'].isin(array)]
# Out:
#       data_somministrazione                fornitore area fascia_anagrafica  \
# 50               2020-12-27          Pfizer/BioNTech  LOM             20-29
# 51               2020-12-27          Pfizer/BioNTech  LOM             30-39
# 52               2020-12-27          Pfizer/BioNTech  LOM             40-49
# 53               2020-12-27          Pfizer/BioNTech  LOM             50-59
# ...                     ...                      ...  ...               ...
# 37020            2021-04-19  Vaxzevria (AstraZeneca)  PIE             50-59
# 37021            2021-04-19  Vaxzevria (AstraZeneca)  PIE             60-69
# 37022            2021-04-19  Vaxzevria (AstraZeneca)  PIE             70-79
# 37023            2021-04-19  Vaxzevria (AstraZeneca)  PIE             80-89
#
#        sesso_maschile  sesso_femminile  \
# 50                 20               22
# 51                 31               33
# 52                 62               80
# 53                114              119
# ...

# %%
df.loc[df['sesso_maschile'] > 100]
# Out:
#       data_somministrazione                fornitore area fascia_anagrafica  \
# 20               2020-12-27          Pfizer/BioNTech  CAM             50-59
# 21               2020-12-27          Pfizer/BioNTech  CAM             60-69
# 53               2020-12-27          Pfizer/BioNTech  LOM             50-59
# 54               2020-12-27          Pfizer/BioNTech  LOM             60-69
# ...                     ...                      ...  ...               ...
# 37037            2021-04-19  Vaxzevria (AstraZeneca)  SAR             70-79
# 37042            2021-04-19  Vaxzevria (AstraZeneca)  SIC             60-69
# 37043            2021-04-19  Vaxzevria (AstraZeneca)  SIC             70-79
# 37048            2021-04-19  Vaxzevria (AstraZeneca)  UMB             70-79
#
#        sesso_maschile  sesso_femminile  \
# 20                119               77
# 21                130               37
# 53                114              119
# 54                160               41
# ...

# %%
df.loc[df['sesso_maschile'] + df["sesso_femminile"] > 200]
# Out:
#       data_somministrazione                fornitore area fascia_anagrafica  \
# 25               2020-12-27          Pfizer/BioNTech  EMR             40-49
# 26               2020-12-27          Pfizer/BioNTech  EMR             50-59
# 53               2020-12-27          Pfizer/BioNTech  LOM             50-59
# 54               2020-12-27          Pfizer/BioNTech  LOM             60-69
# ...                     ...                      ...  ...               ...
# 37037            2021-04-19  Vaxzevria (AstraZeneca)  SAR             70-79
# 37042            2021-04-19  Vaxzevria (AstraZeneca)  SIC             60-69
# 37043            2021-04-19  Vaxzevria (AstraZeneca)  SIC             70-79
# 37048            2021-04-19  Vaxzevria (AstraZeneca)  UMB             70-79
#
#        sesso_maschile  sesso_femminile  \
# 25                 80              146
# 26                 70              217
# 53                114              119
# 54                160               41
# ...

# %%
media = df['sesso_maschile'].mean() + df["sesso_femminile"].mean()
df.loc[df['sesso_maschile'] + df["sesso_femminile"] > media]
# Out:
#       data_somministrazione                fornitore area fascia_anagrafica  \
# 216              2020-12-30          Pfizer/BioNTech  LAZ             40-49
# 217              2020-12-30          Pfizer/BioNTech  LAZ             50-59
# 282              2020-12-31          Pfizer/BioNTech  CAM             50-59
# 288              2020-12-31          Pfizer/BioNTech  EMR             40-49
# ...                     ...                      ...  ...               ...
# 37037            2021-04-19  Vaxzevria (AstraZeneca)  SAR             70-79
# 37042            2021-04-19  Vaxzevria (AstraZeneca)  SIC             60-69
# 37043            2021-04-19  Vaxzevria (AstraZeneca)  SIC             70-79
# 37048            2021-04-19  Vaxzevria (AstraZeneca)  UMB             70-79
#
#        sesso_maschile  sesso_femminile  \
# 216               147              294
# 217               156              280
# 282               231              191
# 288               149              309
# ...

# %%
df['sesso_maschile'].sum() + df["sesso_femminile"].sum()
# Out:
# 15558775

# %%
df.groupby('nome_area')[['sesso_maschile']].sum()
# Out:
#                                 sesso_maschile
# nome_area
# Abruzzo                                 144680
# Basilicata                               58529
# Calabria                                193580
# Campania                                609533
# ...                                        ...
# Toscana                                 408671
# Umbria                                   99024
# Valle d'Aosta / Vallée d'Aoste           15044
# Veneto                                  537404
#
# [21 rows x 1 columns]

# %%
sum_column = df["sesso_maschile"] + df["sesso_femminile"]
df["total"] = sum_column
df.groupby('nome_area')[['total']].sum()
# Out:
#                                   total
# nome_area
# Abruzzo                          344043
# Basilicata                       135940
# Calabria                         406187
# Campania                        1333116
# ...                                 ...
# Toscana                         1015018
# Umbria                           241787
# Valle d'Aosta / Vallée d'Aoste    35033
# Veneto                          1330197
#
# [21 rows x 1 columns]

# %%
total = df['sesso_maschile'].sum() + df["sesso_femminile"].sum()
df.groupby('nome_area')[['total']].sum() / total * 100
# Out:
#                                    total
# nome_area
# Abruzzo                         2.211247
# Basilicata                      0.873719
# Calabria                        2.610662
# Campania                        8.568258
# ...                                  ...
# Toscana                         6.523766
# Umbria                          1.554023
# Valle d'Aosta / Vallée d'Aoste  0.225166
# Veneto                          8.549497
#
# [21 rows x 1 columns]

# %%
reg = df.groupby('nome_area')[['total']].sum()
print(reg > 100000)
# Out:
#                                 total
# nome_area
# Abruzzo                          True
# Basilicata                       True
# Calabria                         True
# Campania                         True
# ...                               ...
# Toscana                          True
# Umbria                           True
# Valle d'Aosta / Vallée d'Aoste  False
# Veneto                           True
#
# [21 rows x 1 columns]
