# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.options.display.max_rows = 8

# %%
df = pd.read_csv("data/vaccini.csv")
df

# %%
x = df.sesso_maschile
y = df.nome_area
plt.scatter(x, y)
plt.show()
